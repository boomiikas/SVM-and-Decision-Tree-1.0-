# %% [markdown]
# Effect of Tree Depth
# Dataset: dt_depth.csv (200 rows, 2 features).
# Task: Train Decision Tree with max_depth=2, 5, None. Compare train/test accuracy.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("dt_depth.csv")

# %%
df.columns
# Out:
# Index(['feature1', 'feature2', 'label'], dtype='object')

# %%
df.head()
# Out:
#    feature1  feature2  label
# 0  2.246588 -1.514550      0
# 1  1.464896 -0.776186      1
# 2 -1.175042 -1.447633      0
# 3 -1.794455  0.459709      0
# 4  0.855820 -0.430646      1

# %%
df.tail()
# Out:
#      feature1  feature2  label
# 195 -0.009200 -1.194385      1
# 196  1.174737  0.878106      0
# 197  0.025602  0.457280      1
# 198  0.952434  0.739700      1
# 199 -1.257558 -0.749535      0

# %%
df.shape
# Out:
# (200, 3)

# %%
df.isnull().sum()
# Out:
# feature1    0
# feature2    0
# label       0
# dtype: int64

# %%
df.isna().sum()
# Out:
# feature1    0
# feature2    0
# label       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.skew()
# Out:
# feature1   -0.130516
# feature2   -0.074816
# label       0.121127
# dtype: float64

# %%
plt.hist(df['feature1'], bins=20, color='skyblue', edgecolor='black')
plt.title('Histogram of Feature1')
plt.show()

# %%
plt.hist(df['feature2'], bins=20, color='green', edgecolor='black')
plt.title('Histogram of Feature2')
plt.show()

# %%
plt.boxplot([df['feature1'], df['feature2']], labels=['feature1', 'feature2'])
plt.title('Box Plot of Features')
plt.legend()
plt.show()
# Out:
# C:\Users\boomi\AppData\Local\Temp\ipykernel_23828\1889216399.py:1: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([df['feature1'], df['feature2']], labels=['feature1', 'feature2'])
# C:\Users\boomi\AppData\Local\Temp\ipykernel_23828\1889216399.py:3: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
plt.scatter(df['feature1'],df['feature2'],c=df['label'],cmap='coolwarm')
plt.xlabel('feature1')
plt.ylabel('feature2')
plt.show()

# %%
plt.plot(df['feature1'], label='Feature1', color='blue')
plt.plot(df['feature2'], label='Feature2', color='green')
plt.title('Line Plot of Features')
plt.xlabel('Index')
plt.ylabel('Value')
plt.legend()
plt.show()

# %%
df.corr()
# Out:
#           feature1  feature2     label
# feature1  1.000000  0.089064  0.657007
# feature2  0.089064  1.000000  0.038839
# label     0.657007  0.038839  1.000000

# %%
sns.heatmap(df.corr(),annot=True,cmap="Blues")
plt.show()

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
X = df.drop(columns='label')
y=df['label']

for depth in [2, 5, None]:
    tree = DecisionTreeClassifier(max_depth=depth, random_state=42)
    tree.fit(X, y)
    acc = accuracy_score(y, tree.predict(X))
    print(f"Max Depth = {depth}, Training Accuracy = {acc:.3f}")
# Out:
# Max Depth = 2, Training Accuracy = 0.870
# Max Depth = 5, Training Accuracy = 0.925
# Max Depth = None, Training Accuracy = 1.000
